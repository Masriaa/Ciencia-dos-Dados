# %% [markdown]
# ### instalar API e importar bibliotecas:

# %%
import sys
# !{sys.executable} -m pip install wbgapi
# Out:
# Requirement already satisfied: wbgapi in c:\users\fevas\onedrive\documentos\github\ciencia-dos-dados\.venv\lib\site-packages (1.0.12)
# Requirement already satisfied: requests in c:\users\fevas\onedrive\documentos\github\ciencia-dos-dados\.venv\lib\site-packages (from wbgapi) (2.32.5)
# Requirement already satisfied: PyYAML in c:\users\fevas\onedrive\documentos\github\ciencia-dos-dados\.venv\lib\site-packages (from wbgapi) (6.0.3)
# Requirement already satisfied: tabulate in c:\users\fevas\onedrive\documentos\github\ciencia-dos-dados\.venv\lib\site-packages (from wbgapi) (0.9.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\fevas\onedrive\documentos\github\ciencia-dos-dados\.venv\lib\site-packages (from requests->wbgapi) (3.4.3)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\fevas\onedrive\documentos\github\ciencia-dos-dados\.venv\lib\site-packages (from requests->wbgapi) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\fevas\onedrive\documentos\github\ciencia-dos-dados\.venv\lib\site-packages (from requests->wbgapi) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\fevas\onedrive\documentos\github\ciencia-dos-dados\.venv\lib\site-packages (from requests->wbgapi) (2025.10.5)

# %%
import wbgapi as wb
import pandas as pd

# %% [markdown]
# ### Seleção das informações (series) que serão incluidas na tabela para análise:

# %% [markdown]
# ##### Para encontrar os códigos referentes a cada indicador, basta ir em https://data.worldbank.org/indicator, selecionar o indicador e copiar o que tem escrito depois da ultima barra da url.

# %%
paises = ['BRA', 'ARG', 'BOL', 'CHL', 'COL', 'ECU', 'PRY', 'PER', 'URY', 'VEN']
periodo = range(2000, 2023)
indicadores = {
    "SP.POP.TOTL": "População Total",
    "SP.DYN.LE00.IN": "Expectativa de Vida",
    "SH.DYN.MORT": "Mortalidade Infantil (por 1000)",
    "SP.ADO.TFRT": "Taxa de fertilidade na adolescência (nascimentos por 1.000 mulheres de 15 a 19 anos)",
    "SH.XPD.CHEX.GD.ZS": "Gastos com Saúde (% do PIB)",
    "SN.ITK.DEFC.ZS": "Prevalência de desnutrição (% da população)",
    "SL.UEM.TOTL.FE.ZS": "Desemprego Feminino (%)",
    "SL.UEM.TOTL.MA.ZS": "Desemprego Masculino (%)",
    "SI.POV.DDAY" : "Taxa de pobreza de US$ 3,00 por dia (%)",
    "EG.ELC.ACCS.ZS": "Acesso à eletricidade (% da população)",
    "SH.STA.BASS.ZS": "Acesso ao Saneamento Básico (%)",
    "SH.H2O.BASW.ZS": "Acesso à Água Potável (%)",
    "NY.GDP.PCAP.KD": "PIB per capita",
    "E.ADT.LITR.ZS": "Taxa de alfabetização, total de adultos (% de pessoas com 15 anos ou mais)",
    "SE.PRM.NENR": "Matrícula escolar primária (% líquida)",
    "SE.SEC.NENR": "Matrícula escolar secundária (% líquida)",
    "SE.TER.ENRR": "Matrícula escolar, terciário (% bruto)",
}

df_data = wb.data.DataFrame(
    list(indicadores.keys()), 
    paises, 
    time=periodo,
    labels=True
)


df_data.head()
# Out:
#                            Country             Series      YR2000      YR2001  \
# economy series
# VEN     SP.POP.TOTL  Venezuela, RB  Population, total  24526708.0  24979922.0
# URY     SP.POP.TOTL        Uruguay  Population, total   3266206.0   3274251.0
# PER     SP.POP.TOTL           Peru  Population, total  26598331.0  26964601.0
# PRY     SP.POP.TOTL       Paraguay  Population, total   5100868.0   5187689.0
# ECU     SP.POP.TOTL        Ecuador  Population, total  12689206.0  12910740.0
#
#                          YR2002      YR2003      YR2004      YR2005  \
# economy series
# VEN     SP.POP.TOTL  25435671.0  25892703.0  26340838.0  26785804.0
# URY     SP.POP.TOTL   3278867.0   3281186.0   3283148.0   3285771.0
# PER     SP.POP.TOTL  27288217.0  27580490.0  27852190.0  28101180.0
# PRY     SP.POP.TOTL   5261328.0   5326436.0   5388175.0   5448097.0
# ECU     SP.POP.TOTL  13138472.0  13372306.0  13608701.0  13846163.0
#
#                          YR2006      YR2007  ...      YR2013      YR2014  \
# economy series                               ...
# VEN     SP.POP.TOTL  27224686.0  27649363.0  ...  29912198.0  30254079.0
# URY     SP.POP.TOTL   3289506.0   3295153.0  ...   3345337.0   3356334.0
# PER     SP.POP.TOTL  28324491.0  28530699.0  ...  29817919.0  30115826.0
# PRY     SP.POP.TOTL   5505148.0   5559386.0  ...   5982445.0   6069811.0
# ECU     SP.POP.TOTL  14086131.0  14328773.0  ...  15807128.0  16035124.0
#
#                          YR2015      YR2016      YR2017      YR2018  \
# economy series
# VEN     SP.POP.TOTL  30573972.0  30765720.0  30565323.0  29807592.0
# URY     SP.POP.TOTL   3368017.0   3379283.0   3388438.0   3394534.0
# PER     SP.POP.TOTL  30457600.0  30866494.0  31324637.0  31897584.0
# PRY     SP.POP.TOTL   6159103.0   6249126.0   6338660.0   6427382.0
# ECU     SP.POP.TOTL  16266225.0  16505139.0  16759519.0  17049547.0
#
#                          YR2019      YR2020      YR2021      YR2022
# economy series
# VEN     SP.POP.TOTL  28938098.0  28444077.0  28237826.0  28213017.0
# URY     SP.POP.TOTL   3397206.0   3398968.0   3396695.0   3390913.0
# PER     SP.POP.TOTL  32449303.0  32838579.0  33155882.0  33475438.0
# PRY     SP.POP.TOTL   6515058.0   6603739.0   6684182.0   6760464.0
# ECU     SP.POP.TOTL  17340021.0  17546065.0  17682454.0  17823897.0
#
# [5 rows x 25 columns]

# %%
df_data.shape
# Out:
# (160, 25)

# %%
df_data.dtypes
# Out:
# Country     object
# Series      object
# YR2000     float64
# YR2001     float64
# YR2002     float64
# YR2003     float64
# YR2004     float64
# YR2005     float64
# YR2006     float64
# YR2007     float64
# YR2008     float64
# YR2009     float64
# YR2010     float64
# YR2011     float64
# YR2012     float64
# YR2013     float64
# YR2014     float64
# YR2015     float64
# YR2016     float64
# YR2017     float64
# YR2018     float64
# YR2019     float64
# YR2020     float64
# YR2021     float64
# YR2022     float64
# dtype: object

# %%
df_data.columns.tolist()
# Out:
# ['Country',
#  'Series',
#  'YR2000',
#  'YR2001',
#  'YR2002',
#  'YR2003',
#  'YR2004',
#  'YR2005',
#  'YR2006',
#  'YR2007',
#  'YR2008',
#  'YR2009',
#  'YR2010',
#  'YR2011',
#  'YR2012',
#  'YR2013',
#  'YR2014',
#  'YR2015',
#  'YR2016',
#  'YR2017',
#  'YR2018',
#  'YR2019',
#  'YR2020',
#  'YR2021',
#  'YR2022']

# %% [markdown]
# ### Tranformar os anos em linhas e o título das series em colunas e adaptar a escrita e o tipo dos anos:

# %%
df_long = df_data.melt(
    id_vars=['Country', 'Series'],   
    var_name='Ano',
    value_name='Valor'
)

df_long['Ano'] = df_long['Ano'].str.replace('YR', '').astype(int)

# %%
df_long.dtypes
# Out:
# Country     object
# Series      object
# Ano          int64
# Valor      float64
# dtype: object

# %%
df_data = df_long.pivot_table(
    index=['Country', 'Ano'],
    columns='Series',
    values='Valor'
).reset_index()

# %% [markdown]
# ### Tabela pronta para análise:

# %%
df_data.head()
# Out:
# Series    Country   Ano  Access to electricity (% of population)  \
# 0       Argentina  2000                                     95.7
# 1       Argentina  2001                                     95.5
# 2       Argentina  2002                                     96.1
# 3       Argentina  2003                                     96.3
# 4       Argentina  2004                                     96.5
#
# Series  Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                                  65.808
# 1                                                  63.491
# 2                                                  62.126
# 3                                                  60.002
# 4                                                  61.681
#
# Series  Current health expenditure (% of GDP)  \
# 0                                    8.220011
# 1                                    8.371799
# 2                                    7.393312
# 3                                    6.894516
# 4                                    7.228683
#
# Series  GDP per capita (constant 2015 US$)  \
# 0                             10631.650364
# 1                             10051.944846
# 2                              8861.561993
# 3                              9545.531941
# 4                             10302.446532
#
# Series  Life expectancy at birth, total (years)  \
# 0                                        73.910
# 1                                        74.154
# 2                                        74.312
# 3                                        74.307
# 4                                        74.871
#
# Series  Mortality rate, under-5 (per 1,000 live births)  \
# 0                                                  19.4
# 1                                                  18.8
# 2                                                  18.3
# 3                                                  17.8
# 4                                                  17.3
#
# Series  People using at least basic drinking water services (% of population)  \
# 0                                               96.284026
# 1                                               96.522820
# 2                                               96.755469
# 3                                               96.982417
# 4                                               97.204346
#
# Series  People using at least basic sanitation services (% of population)  \
# 0                                               87.666927
# 1                                               88.135939
# 2                                               88.603394
# 3                                               89.069563
# 4                                               89.535068
#
# Series  Population, total  \
# 0              37213984.0
# 1              37624825.0
# 2              38029349.0
# 3              38424282.0
# 4              38815916.0
#
# Series  Poverty headcount ratio at $3.00 a day (2021 PPP) (% of population)  \
# 0                                                     7.3
# 1                                                    10.7
# 2                                                    17.1
# 3                                                     8.2
# 4                                                     6.0
#
# Series  Prevalence of undernourishment (% of population)  \
# 0                                                    NaN
# 1                                                    2.9
# 2                                                    3.7
# 3                                                    4.3
# 4                                                    3.9
#
# Series  School enrollment, primary (% net)  \
# 0                                 98.92861
# 1                                 99.00260
# 2                                 98.95948
# 3                                 98.87379
# 4                                 98.57855
#
# Series  School enrollment, secondary (% net)  \
# 0                                   78.48781
# 1                                   78.94955
# 2                                   78.81052
# 3                                   78.51365
# 4                                   78.53653
#
# Series  School enrollment, tertiary (% gross)  \
# 0                                   54.084351
# 1                                   58.469761
# 2                                   61.722881
# 3                                   64.030487
# 4                                   64.589142
#
# Series  Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# 0                                                  16.356
# 1                                                  17.191
# 2                                                  18.823
# 3                                                  17.577
# 4                                                  15.823
#
# Series  Unemployment, male (% of male labor force) (modeled ILO estimate)
# 0                                                  14.029
# 1                                                  17.411
# 2                                                  20.122
# 3                                                  13.806
# 4                                                  11.893

# %%
df_data.shape
# Out:
# (230, 18)

# %%
df_data.columns.tolist()
# Out:
# ['Country',
#  'Ano',
#  'Access to electricity (% of population)',
#  'Adolescent fertility rate (births per 1,000 women ages 15-19)',
#  'Current health expenditure (% of GDP)',
#  'GDP per capita (constant 2015 US$)',
#  'Life expectancy at birth, total (years)',
#  'Mortality rate, under-5 (per 1,000 live births)',
#  'People using at least basic drinking water services (% of population)',
#  'People using at least basic sanitation services (% of population)',
#  'Population, total',
#  'Poverty headcount ratio at $3.00 a day (2021 PPP) (% of population)',
#  'Prevalence of undernourishment (% of population)',
#  'School enrollment, primary (% net)',
#  'School enrollment, secondary (% net)',
#  'School enrollment, tertiary (% gross)',
#  'Unemployment, female (% of female labor force) (modeled ILO estimate)',
#  'Unemployment, male (% of male labor force) (modeled ILO estimate)']

# %%
df_data.isna().sum()
# Out:
# Series
# Country                                                                   0
# Ano                                                                       0
# Access to electricity (% of population)                                   0
# Adolescent fertility rate (births per 1,000 women ages 15-19)             0
# Current health expenditure (% of GDP)                                    18
# GDP per capita (constant 2015 US$)                                       23
# Life expectancy at birth, total (years)                                   0
# Mortality rate, under-5 (per 1,000 live births)                           0
# People using at least basic drinking water services (% of population)     6
# People using at least basic sanitation services (% of population)         6
# Population, total                                                         0
# Poverty headcount ratio at $3.00 a day (2021 PPP) (% of population)      40
# Prevalence of undernourishment (% of population)                         10
# School enrollment, primary (% net)                                       68
# School enrollment, secondary (% net)                                     84
# School enrollment, tertiary (% gross)                                    96
# Unemployment, female (% of female labor force) (modeled ILO estimate)     0
# Unemployment, male (% of male labor force) (modeled ILO estimate)         0
# dtype: int64

# %%
df_data.dtypes
# Out:
# Series
# Country                                                                   object
# Ano                                                                        int64
# Access to electricity (% of population)                                  float64
# Adolescent fertility rate (births per 1,000 women ages 15-19)            float64
# Current health expenditure (% of GDP)                                    float64
# GDP per capita (constant 2015 US$)                                       float64
# Life expectancy at birth, total (years)                                  float64
# Mortality rate, under-5 (per 1,000 live births)                          float64
# People using at least basic drinking water services (% of population)    float64
# People using at least basic sanitation services (% of population)        float64
# Population, total                                                        float64
# Poverty headcount ratio at $3.00 a day (2021 PPP) (% of population)      float64
# Prevalence of undernourishment (% of population)                         float64
# School enrollment, primary (% net)                                       float64
# School enrollment, secondary (% net)                                     float64
# School enrollment, tertiary (% gross)                                    float64
# Unemployment, female (% of female labor force) (modeled ILO estimate)    float64
# Unemployment, male (% of male labor force) (modeled ILO estimate)        float64
# dtype: object

# %% [markdown]
# Tratamento de Dados Faltantes

# %%
linhas_com_nan = df_data[df_data.isna().any(axis=1)]
linhas_com_nan
# Out:
# Series        Country   Ano  Access to electricity (% of population)  \
# 0           Argentina  2000                                     95.7
# 15          Argentina  2015                                     99.7
# 17          Argentina  2017                                    100.0
# 18          Argentina  2018                                    100.0
# 19          Argentina  2019                                    100.0
# ..                ...   ...                                      ...
# 225     Venezuela, RB  2018                                     99.9
# 226     Venezuela, RB  2019                                     99.8
# 227     Venezuela, RB  2020                                     99.9
# 228     Venezuela, RB  2021                                    100.0
# 229     Venezuela, RB  2022                                    100.0
#
# Series  Adolescent fertility rate (births per 1,000 women ages 15-19)  \
# 0                                                  65.808
# 15                                                 63.879
# 17                                                 55.022
# 18                                                 49.926
# 19                                                 41.751
# ..                                                    ...
# 225                                                75.503
# 226                                                74.487
# 227                                                73.750
# 228                                                73.384
# 229                                                73.026
#
# Series  Current health expenditure (% of GDP)  \
# 0                                    8.220011
# 15                                  10.229337
# 17                                  10.231748
# 18                                  10.291469
# 19                                  10.155511
# ..                                        ...
# 225                                  2.416913
# 226                                  2.185637
# 227                                  4.116152
# 228                                  4.102220
# 229                                  4.550474
#
# Series  GDP per capita (constant 2015 US$)  \
# 0                             10631.650364
# 15                            13679.626498
# 17                            13520.112985
# 18                            13058.328545
# 19                            12706.397811
# ..                                     ...
# 225                                    NaN
# 226                                    NaN
# 227                                    NaN
# 228                                    NaN
# 229                                    NaN
#
# Series  Life expectancy at birth, total (years)  \
# 0                                        73.910
# 15                                       76.600
# 17                                       76.543
# 18                                       76.770
# 19                                       76.847
# ..                                          ...
# 225                                      72.641
# 226                                      72.766
# 227                                      72.369
# 228                                      71.536
# 229                                      72.566
#
# Series  Mortality rate, under-5 (per 1,000 live births)  \
# 0                                                  19.4
# 15                                                 11.7
# 17                                                 11.0
# 18                                                 10.7
# 19                                                 10.5
# ..                                                  ...
# 225                                                24.3
# 226                                                24.3
# 227                                                24.3
# 228                                                24.3
# 229                                                24.3
#
# Series  People using at least basic drinking water services (% of population)  \
# 0                                               96.284026
# 15                                              98.982308
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# ..                                                    ...
# 225                                             94.039990
# 226                                             93.862896
# 227                                             93.685801
# 228                                             93.508706
# 229                                             93.331611
#
# Series  People using at least basic sanitation services (% of population)  \
# 0                                               87.666927
# 15                                              94.420408
# 17                                                    NaN
# 18                                                    NaN
# 19                                                    NaN
# ..                                                    ...
# 225                                             96.214417
# 226                                             96.759710
# 227                                             96.986065
# 228                                             97.002357
# 229                                             98.395586
#
# Series  Population, total  \
# 0              37213984.0
# 15             43477012.0
# 17             44288894.0
# 18             44654882.0
# 19             44973465.0
# ..                    ...
# 225            29807592.0
# 226            28938098.0
# 227            28444077.0
# 228            28237826.0
# 229            28213017.0
#
# Series  Poverty headcount ratio at $3.00 a day (2021 PPP) (% of population)  \
# 0                                                     7.3
# 15                                                    NaN
# 17                                                    1.1
# 18                                                    1.6
# 19                                                    1.7
# ..                                                    ...
# 225                                                   NaN
# 226                                                   NaN
# 227                                                   NaN
# 228                                                   NaN
# 229                                                   NaN
#
# Series  Prevalence of undernourishment (% of population)  \
# 0                                                    NaN
# 15                                                   2.8
# 17                                                   3.4
# 18                                                   3.5
# 19                                                   3.5
# ..                                                   ...
# 225                                                 23.2
# 226                                                 23.9
# 227                                                 22.2
# 228                                                 20.0
# 229                                                 17.6
#
# Series  School enrollment, primary (% net)  \
# 0                                 98.92861
# 15                                99.49576
# 17                                99.18400
# 18                                     NaN
# 19                                     NaN
# ..                                     ...
# 225                                    NaN
# 226                                    NaN
# 227                                    NaN
# 228                                    NaN
# 229                                    NaN
#
# Series  School enrollment, secondary (% net)  \
# 0                                   78.48781
# 15                                  88.44048
# 17                                  90.79605
# 18                                       NaN
# 19                                       NaN
# ..                                       ...
# 225                                      NaN
# 226                                      NaN
# 227                                      NaN
# 228                                      NaN
# 229                                      NaN
#
# Series  School enrollment, tertiary (% gross)  \
# 0                                   54.084351
# 15                                  83.755693
# 17                                  89.329735
# 18                                  91.084651
# 19                                  95.192824
# ..                                        ...
# 225                                       NaN
# 226                                       NaN
# 227                                       NaN
# 228                                       NaN
# 229                                       NaN
#
# Series  Unemployment, female (% of female labor force) (modeled ILO estimate)  \
# 0                                                  16.356
# 15                                                  8.706
# 17                                                  9.485
# 18                                                 10.563
# 19                                                 10.718
# ..                                                    ...
# 225                                                 6.167
# 226                                                 6.478
# 227                                                 7.907
# 228                                                 7.548
# 229                                                 6.222
#
# Series  Unemployment, male (% of male labor force) (modeled ILO estimate)
# 0                                                  14.029
# 15                                                  6.798
# 17                                                  7.544
# 18                                                  8.246
# 19                                                  9.202
# ..                                                    ...
# 225                                                 5.001
# 226                                                 5.487
# 227                                                 7.286
# 228                                                 6.705
# 229                                                 5.410
#
# [163 rows x 18 columns]

# %%
df_data.isnull().sum()
# Out:
# Series
# Country                                                                   0
# Ano                                                                       0
# Access to electricity (% of population)                                   0
# Adolescent fertility rate (births per 1,000 women ages 15-19)             0
# Current health expenditure (% of GDP)                                    18
# GDP per capita (constant 2015 US$)                                       23
# Life expectancy at birth, total (years)                                   0
# Mortality rate, under-5 (per 1,000 live births)                           0
# People using at least basic drinking water services (% of population)     6
# People using at least basic sanitation services (% of population)         6
# Population, total                                                         0
# Poverty headcount ratio at $3.00 a day (2021 PPP) (% of population)      40
# Prevalence of undernourishment (% of population)                         10
# School enrollment, primary (% net)                                       68
# School enrollment, secondary (% net)                                     84
# School enrollment, tertiary (% gross)                                    96
# Unemployment, female (% of female labor force) (modeled ILO estimate)     0
# Unemployment, male (% of male labor force) (modeled ILO estimate)         0
# dtype: int64

# %%
colunas_com_nulos = [
    'Current health expenditure (% of GDP)',
    'GDP per capita (constant 2015 US$)',
    'People using at least basic drinking water services (% of population)',
    'People using at least basic sanitation services (% of population)',
    'Poverty headcount ratio at $3.00 a day (2021 PPP) (% of population)',
    'Prevalence of undernourishment (% of population)',
    'School enrollment, primary (% net)',
    'School enrollment, secondary (% net)',
    'School enrollment, tertiary (% gross)'
]

for col in colunas_com_nulos:
    df_data.fillna(df_data[col].median(), inplace=True)

# %%
df_data.isnull().sum()
# Out:
# Series
# Country                                                                  0
# Ano                                                                      0
# Access to electricity (% of population)                                  0
# Adolescent fertility rate (births per 1,000 women ages 15-19)            0
# Current health expenditure (% of GDP)                                    0
# GDP per capita (constant 2015 US$)                                       0
# Life expectancy at birth, total (years)                                  0
# Mortality rate, under-5 (per 1,000 live births)                          0
# People using at least basic drinking water services (% of population)    0
# People using at least basic sanitation services (% of population)        0
# Population, total                                                        0
# Poverty headcount ratio at $3.00 a day (2021 PPP) (% of population)      0
# Prevalence of undernourishment (% of population)                         0
# School enrollment, primary (% net)                                       0
# School enrollment, secondary (% net)                                     0
# School enrollment, tertiary (% gross)                                    0
# Unemployment, female (% of female labor force) (modeled ILO estimate)    0
# Unemployment, male (% of male labor force) (modeled ILO estimate)        0
# dtype: int64
