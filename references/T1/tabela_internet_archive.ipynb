# %%
import pandas as pd

data_dict = {
    'Nome':[
        'identifier',      
        'title',           
        'creator',         
        'date',            
        'subject',          
        'language',         
        'description',      
        'collection',       
        'format',        
        'addeddate',       
        'downloads'
    ],

    'Tipo':[
        'Categorico Nominal',      
        'Categorico Nominal',           
        'Categorico Nominal',         
        'Data/Hora',            
        'Categorico Nominal',          
        'Categorico Nominal',         
        'Categorico Nominal',      
        'Categorico Nominal',       
        'Categorico Nominal',        
        'Data/Hora',     
        'Numérico Discreto' 
    ],

    'Descrição':[
        'Identificador único do texto',
        'Título do texto',
        'Autor do texto',
        'Data de publicação',
        'Palavras-chave do texto',
        'Linguagem do texto',
        'Sinopse ou resumo',
        'Coleções às quais o texto pertence',
        'Formatos disponíveis do arquivo',
        'Data de adição no site',
        'Quantidade baixada'
    ],

    'Dados Faltantes':[
        'Não', 
        'Não', 
        'Sim', 
        'Sim', 
        'Não', 
        'Sim',
        'Sim', 
        'Não', 
        'Não', 
        'Não', 
        'Não'
    ]
}

df = pd.DataFrame(data_dict)
styled_df = df.style.set_table_styles(
    [
        {'selector': 'th', 'props': [('text-align', 'left')]},
        {'selector': 'td', 'props': [('text-align', 'left')]}
    ]
)

print("Período de análise: 2000 a 2025")
print("O conjunto de dados possui mais de 9000 amostras e 11 features.")
display(styled_df)
# Out:
# Período de análise: 2000 a 2025
# O conjunto de dados possui mais de 9000 amostras e 11 features.
# <style type="text/css">
# #T_15d98 th {
#   text-align: left;
# }
# #T_15d98 td {
#   text-align: left;
# }
# </style>
# <table id="T_15d98">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_15d98_level0_col0" class="col_heading level0 col0" >Nome</th>
#       <th id="T_15d98_level0_col1" class="col_heading level0 col1" >Tipo</th>
#       <th id="T_15d98_level0_col2" class="col_heading level0 col2" >Descrição</th>
#       <th id="T_15d98_level0_col3" class="col_heading level0 col3" >Dados Faltantes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_15d98_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_15d98_row0_col0" class="data row0 col0" >identifier</td>
#       <td id="T_15d98_row0_col1" class="data row0 col1" >Categorico Nominal</td>
# ...
