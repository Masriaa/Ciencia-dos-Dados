# %%
pip install Jinja2
# Out:
# Requirement already satisfied: Jinja2 in c:\users\conta\downloads\cdd\.venv\lib\site-packages (3.1.6)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\conta\downloads\cdd\.venv\lib\site-packages (from Jinja2) (3.0.3)
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

dict = {
    'Nome':[
        'identifier',      
        'title',           
        'creator',         
        'date',            
        'subject',          
        'language',         
        'description',      
        'collection',       
        'format',        
        'addeddate',       
        'downloads'
    ],

    'Tipo':[
        'Categorico Nominal',      
        'Categorico Nominal',           
        'Categorico Nominal',         
        'Data/Hora',            
        'Categorico Nominal',          
        'Categorico Nominal',         
        'Categorico Nominal',      
        'Categorico Nominal',       
        'Categorico Nominal',        
        'Data/Hora',     
        'Numerico discreto' 
    ],

    'Descrição':[
        'Identificador único do texto',
        'Tiltulo do texto',
        'Autor do texto',
        'Data de publicação',
        'Palavras chaves do texto',
        'Linguaguem do texto',
        'Sinopse ou resumo',
        'Coleção(s) a qual o texto pertence',
        'Formatos disponíveis do arquivo',
        'Data de adição no site',
        'Quantidade baixado'
    ],

    'Dados_Faltantes':[
        'Não', 
        'Não', 
        'Sim', 
        'Sim', 
        'Nao', 
        'Sim',
        'Sim', 
        'Não', 
        'Não', 
        'Não', 
        'Não'
    ]
}

df = pd.DataFrame(dict)
styled_df = df.style.set_table_styles(
    [
        {'selector': 'th', 'props': [('text-align', 'left')]},
        {'selector': 'td', 'props': [('text-align', 'left')]}
    ]
)

print("Período de análise: 2000 a 2025")
print("O conjunto de dados possui 9134 amostras e 11 features.")
display(styled_df)
# Out:
# Período de análise: 2000 a 2025
# O conjunto de dados possui 9134 amostras e 11 features.
# <style type="text/css">
# #T_dfa48 th {
#   text-align: left;
# }
# #T_dfa48 td {
#   text-align: left;
# }
# </style>
# <table id="T_dfa48">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_dfa48_level0_col0" class="col_heading level0 col0" >Nome</th>
#       <th id="T_dfa48_level0_col1" class="col_heading level0 col1" >Tipo</th>
#       <th id="T_dfa48_level0_col2" class="col_heading level0 col2" >Descrição</th>
#       <th id="T_dfa48_level0_col3" class="col_heading level0 col3" >Dados_Faltantes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_dfa48_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_dfa48_row0_col0" class="data row0 col0" >identifier</td>
#       <td id="T_dfa48_row0_col1" class="data row0 col1" >Categorico Nominal</td>
#       <td id="T_dfa48_row0_col2" class="data row0 col2" >Identificador único do texto</td>
#       <td id="T_dfa48_row0_col3" class="data row0 col3" >Não</td>
#     </tr>
#     <tr>
#       <th id="T_dfa48_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_dfa48_row1_col0" class="data row1 col0" >title</td>
#       <td id="T_dfa48_row1_col1" class="data row1 col1" >Categorico Nominal</td>
#       <td id="T_dfa48_row1_col2" class="data row1 col2" >Tiltulo do texto</td>
#       <td id="T_dfa48_row1_col3" class="data row1 col3" >Não</td>
#     </tr>
#     <tr>
#       <th id="T_dfa48_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_dfa48_row2_col0" class="data row2 col0" >creator</td>
#       <td id="T_dfa48_row2_col1" class="data row2 col1" >Categorico Nominal</td>
#       <td id="T_dfa48_row2_col2" class="data row2 col2" >Autor do texto</td>
#       <td id="T_dfa48_row2_col3" class="data row2 col3" >Sim</td>
#     </tr>
#     <tr>
#       <th id="T_dfa48_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_dfa48_row3_col0" class="data row3 col0" >date</td>
#       <td id="T_dfa48_row3_col1" class="data row3 col1" >Data/Hora</td>
#       <td id="T_dfa48_row3_col2" class="data row3 col2" >Data de publicação</td>
#       <td id="T_dfa48_row3_col3" class="data row3 col3" >Sim</td>
#     </tr>
#     <tr>
#       <th id="T_dfa48_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_dfa48_row4_col0" class="data row4 col0" >subject</td>
#       <td id="T_dfa48_row4_col1" class="data row4 col1" >Categorico Nominal</td>
#       <td id="T_dfa48_row4_col2" class="data row4 col2" >Palavras chaves do texto</td>
#       <td id="T_dfa48_row4_col3" class="data row4 col3" >Nao</td>
#     </tr>
#     <tr>
#       <th id="T_dfa48_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_dfa48_row5_col0" class="data row5 col0" >language</td>
#       <td id="T_dfa48_row5_col1" class="data row5 col1" >Categorico Nominal</td>
#       <td id="T_dfa48_row5_col2" class="data row5 col2" >Linguaguem do texto</td>
#       <td id="T_dfa48_row5_col3" class="data row5 col3" >Sim</td>
#     </tr>
#     <tr>
#       <th id="T_dfa48_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_dfa48_row6_col0" class="data row6 col0" >description</td>
#       <td id="T_dfa48_row6_col1" class="data row6 col1" >Categorico Nominal</td>
#       <td id="T_dfa48_row6_col2" class="data row6 col2" >Sinopse ou resumo</td>
#       <td id="T_dfa48_row6_col3" class="data row6 col3" >Sim</td>
#     </tr>
#     <tr>
#       <th id="T_dfa48_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_dfa48_row7_col0" class="data row7 col0" >collection</td>
#       <td id="T_dfa48_row7_col1" class="data row7 col1" >Categorico Nominal</td>
#       <td id="T_dfa48_row7_col2" class="data row7 col2" >Coleção(s) a qual o texto pertence</td>
#       <td id="T_dfa48_row7_col3" class="data row7 col3" >Não</td>
#     </tr>
#     <tr>
#       <th id="T_dfa48_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_dfa48_row8_col0" class="data row8 col0" >format</td>
#       <td id="T_dfa48_row8_col1" class="data row8 col1" >Categorico Nominal</td>
#       <td id="T_dfa48_row8_col2" class="data row8 col2" >Formatos disponíveis do arquivo</td>
#       <td id="T_dfa48_row8_col3" class="data row8 col3" >Não</td>
#     </tr>
#     <tr>
#       <th id="T_dfa48_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_dfa48_row9_col0" class="data row9 col0" >addeddate</td>
#       <td id="T_dfa48_row9_col1" class="data row9 col1" >Data/Hora</td>
#       <td id="T_dfa48_row9_col2" class="data row9 col2" >Data de adição no site</td>
#       <td id="T_dfa48_row9_col3" class="data row9 col3" >Não</td>
#     </tr>
#     <tr>
#       <th id="T_dfa48_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_dfa48_row10_col0" class="data row10 col0" >downloads</td>
#       <td id="T_dfa48_row10_col1" class="data row10 col1" >Numerico discreto</td>
#       <td id="T_dfa48_row10_col2" class="data row10 col2" >Quantidade baixado</td>
#       <td id="T_dfa48_row10_col3" class="data row10 col3" >Não</td>
#     </tr>
#   </tbody>
# </table>
