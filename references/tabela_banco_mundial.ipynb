# %%
pip install jinja2
# Out:
# Collecting jinja2
#   Downloading jinja2-3.1.6-py3-none-any.whl.metadata (2.9 kB)
# Collecting MarkupSafe>=2.0 (from jinja2)
#   Downloading markupsafe-3.0.3-cp313-cp313-win_amd64.whl.metadata (2.8 kB)
# Downloading jinja2-3.1.6-py3-none-any.whl (134 kB)
# Downloading markupsafe-3.0.3-cp313-cp313-win_amd64.whl (15 kB)
# Installing collected packages: MarkupSafe, jinja2
#
#    -------------------- ------------------- 1/2 [jinja2]
#    -------------------- ------------------- 1/2 [jinja2]
#    ---------------------------------------- 2/2 [jinja2]
#
# Successfully installed MarkupSafe-3.0.3 jinja2-3.1.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

dict = {
    'Nome':[
        'Series',
        'Country',
        'Ano',
        'Access to electricity (% of population)',
        'Adolescent fertility rate (births per 1,000 women ages 15-19)',
        'Current health expenditure (% of GDP)',
        'GDP per capita (constant 2015 US$)',
        'Life expectancy at birth, total (years)',
        'Mortality rate, under-5 (per 1,000 live births)',
        'People using at least basic drinking water services (% of population)',
        'People using at least basic sanitation services (% of population)',
        'Population, total',
        'Poverty headcount ratio at $3.00 a day (2021 PPP) (% of population)',
        'Prevalence of undernourishment (% of population)',
        'School enrollment, primary (% net)',
        'School enrollment, secondary (% net)',
        'School enrollment, tertiary (% gross)',
        'Unemployment, female (% of female labor force) (modeled ILO estimate)',
        'Unemployment, male (% of male labor force) (modeled ILO estimate)'
    ],
    'Tipo':[
        'Categórico Discreto',
        'Categórico Nominal',
        'Numérico Discreto',
        'Numérico Contínuo',
        'Numérico Contínuo',
        'Numérico Contínuo',
        'Numérico Contínuo',
        'Numérico Contínuo',
        'Numérico Contínuo',
        'Numérico Contínuo',
        'Numérico Contínuo',
        'Numérico Discreto',
        'Numérico Contínuo',
        'Numérico Contínuo',
        'Numérico Contínuo',
        'Numérico Contínuo',
        'Numérico Contínuo',
        'Numérico Contínuo',
        'Numérico Contínuo'
    ],
    'Descrição':[
        "id para a tupla",
        "Nome do país ao qual os dados da linha se referem.",
        "Ano em que os dados do indicador foram registrados.",
        "EG.ELC.ACCS.ZS: Acesso à eletricidade (% da população)",
        "SP.ADO.TFRT: Taxa de fertilidade na adolescência (nascimentos por 1.000 mulheres de 15 a 19 anos)",
        "SH.XPD.CHEX.GD.ZS: Gastos com Saúde (% do PIB)",
        "NY.GDP.PCAP.KD: PIB per capita",
        "SP.DYN.LE00.IN: Expectativa de Vida",
        "SH.DYN.MORT: Mortalidade Infantil (por 1000)",
        "SH.H2O.BASW.ZS: Acesso à Água Potável (%)",
        "SH.STA.BASS.ZS: Acesso ao Saneamento Básico (%)",
        "SP.POP.TOTL: População Total",
        "SI.POV.DDAY: Taxa de pobreza de US$ 3,00 por dia (%)",
        "SN.ITK.DEFC.ZS: Prevalência de desnutrição (% da população)",
        "SE.PRM.NENR: Matrícula escolar primária (% líquida)",
        "SE.SEC.NENR: Matrícula escolar secundária (% líquida)",
        "SE.TER.ENRR: Matrícula escolar, terciário (% bruto)",
        "SL.UEM.TOTL.FE.ZS: Desemprego Feminino (%)",
        "SL.UEM.TOTL.MA.ZS: Desemprego Masculino (%)"
    ],
    'Dados_Faltantes':[
        'Não',
        'Não',
        'Não',
        'Não',
        'Não',
        'Sim',
        'Sim',
        'Não',
        'Não',
        'Sim',
        'Sim',
        'Não',
        'Sim',
        'Sim',
        'Sim',
        'Sim',
        'Sim',
        'Não',
        'Não'
    ]
}

df = pd.DataFrame(dict)
styled_df = df.style.set_table_styles(
    [
        {'selector': 'th', 'props': [('text-align', 'left')]},
        {'selector': 'td', 'props': [('text-align', 'left')]}
    ]
)

print("Período de análise: 2000 a 2023")
print("O conjunto de dados possui 230 amostras e 17 features.")
display(styled_df)
# Out:
# Período de análise: 2000 a 2023
# O conjunto de dados possui 230 amostras e 17 features.
# <style type="text/css">
# #T_2dd2e th {
#   text-align: left;
# }
# #T_2dd2e td {
#   text-align: left;
# }
# </style>
# <table id="T_2dd2e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2dd2e_level0_col0" class="col_heading level0 col0" >Nome</th>
#       <th id="T_2dd2e_level0_col1" class="col_heading level0 col1" >Tipo</th>
#       <th id="T_2dd2e_level0_col2" class="col_heading level0 col2" >Descrição</th>
#       <th id="T_2dd2e_level0_col3" class="col_heading level0 col3" >Dados_Faltantes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2dd2e_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_2dd2e_row0_col0" class="data row0 col0" >Series</td>
#       <td id="T_2dd2e_row0_col1" class="data row0 col1" >Categórico Discreto</td>
#       <td id="T_2dd2e_row0_col2" class="data row0 col2" >id para a tupla</td>
#       <td id="T_2dd2e_row0_col3" class="data row0 col3" >Não</td>
#     </tr>
#     <tr>
#       <th id="T_2dd2e_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_2dd2e_row1_col0" class="data row1 col0" >Country</td>
#       <td id="T_2dd2e_row1_col1" class="data row1 col1" >Categórico Nominal</td>
#       <td id="T_2dd2e_row1_col2" class="data row1 col2" >Nome do país ao qual os dados da linha se referem.</td>
#       <td id="T_2dd2e_row1_col3" class="data row1 col3" >Não</td>
#     </tr>
#     <tr>
#       <th id="T_2dd2e_level0_row2" class="row_heading level0 row2" >2</th>
#       <td id="T_2dd2e_row2_col0" class="data row2 col0" >Ano</td>
#       <td id="T_2dd2e_row2_col1" class="data row2 col1" >Numérico Discreto</td>
#       <td id="T_2dd2e_row2_col2" class="data row2 col2" >Ano em que os dados do indicador foram registrados.</td>
#       <td id="T_2dd2e_row2_col3" class="data row2 col3" >Não</td>
#     </tr>
#     <tr>
#       <th id="T_2dd2e_level0_row3" class="row_heading level0 row3" >3</th>
#       <td id="T_2dd2e_row3_col0" class="data row3 col0" >Access to electricity (% of population)</td>
#       <td id="T_2dd2e_row3_col1" class="data row3 col1" >Numérico Contínuo</td>
#       <td id="T_2dd2e_row3_col2" class="data row3 col2" >EG.ELC.ACCS.ZS: Acesso à eletricidade (% da população)</td>
#       <td id="T_2dd2e_row3_col3" class="data row3 col3" >Não</td>
#     </tr>
#     <tr>
#       <th id="T_2dd2e_level0_row4" class="row_heading level0 row4" >4</th>
#       <td id="T_2dd2e_row4_col0" class="data row4 col0" >Adolescent fertility rate (births per 1,000 women ages 15-19)</td>
#       <td id="T_2dd2e_row4_col1" class="data row4 col1" >Numérico Contínuo</td>
#       <td id="T_2dd2e_row4_col2" class="data row4 col2" >SP.ADO.TFRT: Taxa de fertilidade na adolescência (nascimentos por 1.000 mulheres de 15 a 19 anos)</td>
#       <td id="T_2dd2e_row4_col3" class="data row4 col3" >Não</td>
#     </tr>
#     <tr>
#       <th id="T_2dd2e_level0_row5" class="row_heading level0 row5" >5</th>
#       <td id="T_2dd2e_row5_col0" class="data row5 col0" >Current health expenditure (% of GDP)</td>
#       <td id="T_2dd2e_row5_col1" class="data row5 col1" >Numérico Contínuo</td>
#       <td id="T_2dd2e_row5_col2" class="data row5 col2" >SH.XPD.CHEX.GD.ZS: Gastos com Saúde (% do PIB)</td>
#       <td id="T_2dd2e_row5_col3" class="data row5 col3" >Sim</td>
#     </tr>
#     <tr>
#       <th id="T_2dd2e_level0_row6" class="row_heading level0 row6" >6</th>
#       <td id="T_2dd2e_row6_col0" class="data row6 col0" >GDP per capita (constant 2015 US$)</td>
#       <td id="T_2dd2e_row6_col1" class="data row6 col1" >Numérico Contínuo</td>
#       <td id="T_2dd2e_row6_col2" class="data row6 col2" >NY.GDP.PCAP.KD: PIB per capita</td>
#       <td id="T_2dd2e_row6_col3" class="data row6 col3" >Sim</td>
#     </tr>
#     <tr>
#       <th id="T_2dd2e_level0_row7" class="row_heading level0 row7" >7</th>
#       <td id="T_2dd2e_row7_col0" class="data row7 col0" >Life expectancy at birth, total (years)</td>
#       <td id="T_2dd2e_row7_col1" class="data row7 col1" >Numérico Contínuo</td>
#       <td id="T_2dd2e_row7_col2" class="data row7 col2" >SP.DYN.LE00.IN: Expectativa de Vida</td>
#       <td id="T_2dd2e_row7_col3" class="data row7 col3" >Não</td>
#     </tr>
#     <tr>
#       <th id="T_2dd2e_level0_row8" class="row_heading level0 row8" >8</th>
#       <td id="T_2dd2e_row8_col0" class="data row8 col0" >Mortality rate, under-5 (per 1,000 live births)</td>
#       <td id="T_2dd2e_row8_col1" class="data row8 col1" >Numérico Contínuo</td>
#       <td id="T_2dd2e_row8_col2" class="data row8 col2" >SH.DYN.MORT: Mortalidade Infantil (por 1000)</td>
#       <td id="T_2dd2e_row8_col3" class="data row8 col3" >Não</td>
#     </tr>
#     <tr>
#       <th id="T_2dd2e_level0_row9" class="row_heading level0 row9" >9</th>
#       <td id="T_2dd2e_row9_col0" class="data row9 col0" >People using at least basic drinking water services (% of population)</td>
#       <td id="T_2dd2e_row9_col1" class="data row9 col1" >Numérico Contínuo</td>
#       <td id="T_2dd2e_row9_col2" class="data row9 col2" >SH.H2O.BASW.ZS: Acesso à Água Potável (%)</td>
#       <td id="T_2dd2e_row9_col3" class="data row9 col3" >Sim</td>
#     </tr>
#     <tr>
#       <th id="T_2dd2e_level0_row10" class="row_heading level0 row10" >10</th>
#       <td id="T_2dd2e_row10_col0" class="data row10 col0" >People using at least basic sanitation services (% of population)</td>
#       <td id="T_2dd2e_row10_col1" class="data row10 col1" >Numérico Contínuo</td>
#       <td id="T_2dd2e_row10_col2" class="data row10 col2" >SH.STA.BASS.ZS: Acesso ao Saneamento Básico (%)</td>
#       <td id="T_2dd2e_row10_col3" class="data row10 col3" >Sim</td>
#     </tr>
#     <tr>
#       <th id="T_2dd2e_level0_row11" class="row_heading level0 row11" >11</th>
#       <td id="T_2dd2e_row11_col0" class="data row11 col0" >Population, total</td>
#       <td id="T_2dd2e_row11_col1" class="data row11 col1" >Numérico Discreto</td>
#       <td id="T_2dd2e_row11_col2" class="data row11 col2" >SP.POP.TOTL: População Total</td>
#       <td id="T_2dd2e_row11_col3" class="data row11 col3" >Não</td>
#     </tr>
#     <tr>
#       <th id="T_2dd2e_level0_row12" class="row_heading level0 row12" >12</th>
#       <td id="T_2dd2e_row12_col0" class="data row12 col0" >Poverty headcount ratio at $3.00 a day (2021 PPP) (% of population)</td>
#       <td id="T_2dd2e_row12_col1" class="data row12 col1" >Numérico Contínuo</td>
#       <td id="T_2dd2e_row12_col2" class="data row12 col2" >SI.POV.DDAY: Taxa de pobreza de US$ 3,00 por dia (%)</td>
#       <td id="T_2dd2e_row12_col3" class="data row12 col3" >Sim</td>
#     </tr>
#     <tr>
#       <th id="T_2dd2e_level0_row13" class="row_heading level0 row13" >13</th>
#       <td id="T_2dd2e_row13_col0" class="data row13 col0" >Prevalence of undernourishment (% of population)</td>
#       <td id="T_2dd2e_row13_col1" class="data row13 col1" >Numérico Contínuo</td>
#       <td id="T_2dd2e_row13_col2" class="data row13 col2" >SN.ITK.DEFC.ZS: Prevalência de desnutrição (% da população)</td>
#       <td id="T_2dd2e_row13_col3" class="data row13 col3" >Sim</td>
#     </tr>
#     <tr>
#       <th id="T_2dd2e_level0_row14" class="row_heading level0 row14" >14</th>
#       <td id="T_2dd2e_row14_col0" class="data row14 col0" >School enrollment, primary (% net)</td>
#       <td id="T_2dd2e_row14_col1" class="data row14 col1" >Numérico Contínuo</td>
#       <td id="T_2dd2e_row14_col2" class="data row14 col2" >SE.PRM.NENR: Matrícula escolar primária (% líquida)</td>
#       <td id="T_2dd2e_row14_col3" class="data row14 col3" >Sim</td>
#     </tr>
#     <tr>
#       <th id="T_2dd2e_level0_row15" class="row_heading level0 row15" >15</th>
#       <td id="T_2dd2e_row15_col0" class="data row15 col0" >School enrollment, secondary (% net)</td>
#       <td id="T_2dd2e_row15_col1" class="data row15 col1" >Numérico Contínuo</td>
#       <td id="T_2dd2e_row15_col2" class="data row15 col2" >SE.SEC.NENR: Matrícula escolar secundária (% líquida)</td>
#       <td id="T_2dd2e_row15_col3" class="data row15 col3" >Sim</td>
#     </tr>
#     <tr>
#       <th id="T_2dd2e_level0_row16" class="row_heading level0 row16" >16</th>
#       <td id="T_2dd2e_row16_col0" class="data row16 col0" >School enrollment,
