# %%
import pandas as pd

dict = {
    'Nome': [
        'Rank', 
        'Name', 
        'Language', 
        'MOST_STREAMED_GAME', 
        '2ND_MOST_STREAMED_GAME',
        'AVERAGE_STREAM_DURATION', 
        'FOLLOWERS_GAINED_PER_STREAM', 
        'AVG_VIEWERS_PER_STREAM',
        'AVG_GAMES_PER_STREAM', 
        'TOTAL_FOLLOWERS', 
        'TOTAL_VIEWS',
        'TOTAL_GAMES_STREAMED', 
        'ACTIVE_DAYS_PER_WEEK', 
        'MOST_ACTIVE_DAY', 
        'DAY_WITH_MOST_FOLLOWERS_GAINED'
    ],
    'Descrição': [
        'Posição do streamer no ranking global do Twitch Tracker durante o período.',
        'Nome de usuário do streamer na Twitch.',
        'Idioma principal do streamer.',
        'Categoria mais transmitida pelo streamer durante o período.',
        'Segunda categoria mais transmitida pelo streamer durante o período.',
        'Média de duração da transmissão do streamer durante o período.',
        'Média de novos seguidores ganhos por transmissão durante o período.',
        'Média de espectadores simultâneos por transmissão durante o período.',
        'Média de categorias diferentes por transmissão durante o período.',
        'Total de seguidores do streamer durante toda sua carreira até o final do período.',
        'Total de visualizações do canal do streamer durante toda sua carreira até o final do período.',
        'Total de categorias transmitidas pelo streamer durante toda a sua carreira até o final do período.',
        'Média de dias por semana em que o streamer realizou uma transmissão durante o período.',
        'Dia na semana no qual o streamer acumulou mais horas transmitidas durante o período.',
        'Dia na semana na qual o streamer ganhou mais seguidores durante o período.'
    ],
    'Tipo': [
        'Categórico Ordinal',
        'Textual',
        'Categórico Nominal',
        'Categórico Nominal',
        'Categórico Nominal',
        'Numérico Contínuo',
        'Numérico Discreto',
        'Numérico Discreto',
        'Numérico Contínuo',
        'Numérico Discreto',
        'Numérico Discreto',
        'Numérico Discreto',
        'Numérico Contínuo',
        'Categórico Nominal',
        'Categórico Nominal'
    ],
    'Dados Faltantes': [
        'Não', 
        'Não', 
        'Não', 
        'Não', 
        'Sim', 
        'Não',
        'Não', 
        'Não', 
        'Não', 
        'Não', 
        'Não', 
        'Não', 
        'Não', 
        'Não', 
        'Não'
    ]
}

df = pd.DataFrame(dict)
styled_df = df.style.set_table_styles(
    [
        {'selector': 'th', 'props': [('text-align', 'left')]},
        {'selector': 'td', 'props': [('text-align', 'left')]}
    ]
)

print("Período de análise: 23 de abril a 23 de maio de 2024.")
print("O conjunto de dados possui 999 amostras e 17 features.")
display(styled_df)
# Out:
# Período de análise: 23 de abril a 23 de maio de 2024.
# O conjunto de dados possui 999 amostras e 17 features.
# <style type="text/css">
# #T_1aebf th {
#   text-align: left;
# }
# #T_1aebf td {
#   text-align: left;
# }
# </style>
# <table id="T_1aebf">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_1aebf_level0_col0" class="col_heading level0 col0" >Nome</th>
#       <th id="T_1aebf_level0_col1" class="col_heading level0 col1" >Descrição</th>
#       <th id="T_1aebf_level0_col2" class="col_heading level0 col2" >Tipo</th>
#       <th id="T_1aebf_level0_col3" class="col_heading level0 col3" >Dados Faltantes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_1aebf_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_1aebf_row0_col0" class="data row0 col0" >Rank</td>
#       <td id="T_1aebf_row0_col1" class="data row0 col1" >Posição do streamer no ranking global do Twitch Tracker durante o período.</td>
# ...
